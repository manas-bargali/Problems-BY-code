# %%
class Solution:
    def LinearSearch(self,l,key):
        for i in l:
            if i==key:
                return l.index(i)
        return -1

# %%
obj=Solution()
obj.LinearSearch([1,2,3,8,10,4,1000],5)
# Out:
# -1
